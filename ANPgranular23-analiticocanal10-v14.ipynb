# %%
import time
tempo_inicio = time.time()

# %%
from datetime import datetime
start = datetime.now()

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Bibliotecas Necessárias**

# %%
import pandas as pd
import numpy  as np
from datetime import datetime, date
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

import plotly.express as px 
import plotly.graph_objects as go
#import dash  
#import dash_core_components as dcc
#import dash_html_components as html
#from dash.dependencies import Input, Output
#import dash_bootstrap_components as dbc


# Visualização
import matplotlib.pyplot as plt
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.graph_objs import *

import seaborn as sns
import cufflinks as cf
from plotly.offline import plot, iplot
import plotly.offline as py
import plotly.graph_objs as go
cf.go_offline()
import plotly.express as px
import plotly.subplots as sp

#from datetime import datetime
from dateutil.relativedelta import relativedelta

#from dash import Dash, dash_table
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## **Definindo a Origem dos Dados**

# %%
#from google.colab import drive
#drive.mount("/content/drive", force_remount=True)
path1='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Tableau/churn/arquivos churn python/'
path2='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/output notebooks/output_models/'
path3='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/output notebooks/volumetria/'
path4='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/output notebooks/histdiesel/'
path5='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/output notebooks/volumetria_arquivos/'
path6='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados VIBRA/'
path7='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/output notebooks/Motor Potencial/'
path8='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados ANP granulares/'
path9='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados ANP granulares/tabela-apoio-isimp-vigente/'
path10='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados ANP granulares/outputs/'
path11='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados ANP granulares/'
path12='C:/Users/YC9R/VIBRA/Customer Insights - Documentos/Avanade Documentos/dados ANP granulares/DIESEL/'

# %% [markdown]
# ## **Definições Gerais**

# %% [markdown]
# ### leitura

# %%
def VIBRA_outliers23 ():
    dfBase = pd.read_parquet('VIBRA_outliers23.parquet' )
    return (dfBase)

def VIBRA_grandes23 ():
    dfBase = pd.read_parquet('VIBRA_grandes23.parquet' )
    return (dfBase)

def VIBRA_medio_grandes23 ():
    dfBase = pd.read_parquet('VIBRA_medio_grandes23.parquet' )
    return (dfBase)

def VIBRA_medio23 ():
    dfBase = pd.read_parquet('VIBRA_medio23.parquet' )
    return (dfBase)

def VIBRA_pequeno_medio23 ():
    dfBase = pd.read_parquet('VIBRA_pequeno_medio23.parquet' )
    return (dfBase)

def VIBRA_pequenos23 ():
    dfBase = pd.read_parquet('VIBRA_pequenos23.parquet' )
    return (dfBase)

def VIBRA_nanicos23 ():
    dfBase = pd.read_parquet('VIBRA_nanicos23.parquet' )
    return (dfBase)

# %%
def VIBRA_outliers22 ():
    dfBase = pd.read_parquet('VIBRA_outliers22.parquet' )
    return (dfBase)

def VIBRA_grandes22 ():
    dfBase = pd.read_parquet('VIBRA_grandes22.parquet' )
    return (dfBase)

def VIBRA_medio_grandes22 ():
    dfBase = pd.read_parquet('VIBRA_medio_grandes22.parquet' )
    return (dfBase)

def VIBRA_medio22 ():
    dfBase = pd.read_parquet('VIBRA_medio22.parquet' )
    return (dfBase)

def VIBRA_pequeno_medio22 ():
    dfBase = pd.read_parquet('VIBRA_pequeno_medio22.parquet' )
    return (dfBase)

def VIBRA_pequenos22 ():
    dfBase = pd.read_parquet('VIBRA_pequenos22.parquet' )
    return (dfBase)

def VIBRA_nanicos22 ():
    dfBase = pd.read_parquet('VIBRA_nanicos22.parquet' )
    return (dfBase)

# %%
def table_queda ():
    dfBase = pd.read_parquet('table_queda.parquet' )
    return (dfBase)

# %%
def df ():
    dfBase = pd.read_parquet('df.parquet' )
    return (dfBase)

# %%
def ft ():
    dfBase = pd.read_parquet('ft.parquet' )
    return (dfBase)

# %%
def od23_clusters ():
    dfBase = pd.read_parquet('od23_clusters.parquet' )
    return (dfBase)

# %% [markdown]
# # tendências df completo

# %%
df = df()
ft = ft()
od23_clusters = od23_clusters()

# %%
#df.info()

df_group = df.groupby("faixa_razao")
df_group['VolANP'].max()
# Out:
# faixa_razao
# grandes          20260.70
# medio             5083.00
# medio_grandes     6668.00
# nanicos            720.00
# outliers         24252.27
# pequeno_medio    12970.99
# pequenos          3394.00
# Name: VolANP, dtype: float64

# %%
mask1 = df["QUALIF_DEST"] == "CONSUMIDOR FINAL"
dfcf = df[mask1]

mask1 = dfcf["faixa_razao"] == "grandes"
grandes10 = dfcf[mask1]

mask1 = grandes10["ano"] == "2023"
grandes10_23 = grandes10[mask1]
#grandes10_23.info()

mask1 = grandes10["ano"] == "2022"
grandes10_22 = grandes10[mask1]
#grandes10_22.info()

# %%
mask1 = grandes10["NOM_ESTADO_dest"] == "SAO PAULO"
grandes10_SP = grandes10[mask1]

mask1 = grandes10["NOM_ESTADO_dest"] == "MINAS GERAIS"
grandes10_MG = grandes10[mask1]

mask1 = grandes10["NOM_ESTADO_dest"] == "PARANA"
grandes10_PR = grandes10[mask1]

mask1 = grandes10["NOM_ESTADO_dest"] == "RIO DE JANEIRO"
grandes10_RJ = grandes10[mask1]

mask1 = grandes10["NOM_ESTADO_dest"] == "BAHIA"
grandes10_BA = grandes10[mask1]

mask1 = grandes10["NOM_ESTADO_dest"] == "MATO GROSSO DO SUL"
grandes10_MS = grandes10[mask1]

# %%
mask1 = grandes10_SP["ano"] == "2023"
grandes10_SP_23 = grandes10_SP[mask1]

mask1 = grandes10_MG["ano"] == "2023"
grandes10_MG_23 = grandes10_MG[mask1]

mask1 = grandes10_PR["ano"] == "2023"
grandes10_PR_23 = grandes10_PR[mask1]

mask1 = grandes10_RJ["ano"] == "2023"
grandes10_RJ_23 = grandes10_RJ[mask1]

mask1 = grandes10_BA["ano"] == "2023"
grandes10_BA_23 = grandes10_BA[mask1]

mask1 = grandes10_MS["ano"] == "2023"
grandes10_MS_23 = grandes10_MS[mask1]

# %% [markdown]
# # grandes

# %%
qd =  grandes10_23.groupby(by='mes')['VolANP'].sum()
qo =  grandes10_22.groupby(by='mes')['VolANP'].sum()
qd = round(qd, 2)
qo = round(qo, 2)

trace1 = go.Bar(y=qd.values,
                x=qd.index,
                name = "Canal 10 - 23 - grandes",
                marker= dict (color ='#fdcdac' ),
                text=qd.values,
                orientation='v'
              )

trace2 = go.Bar(y=qo.values,
                x=qo.index,
                name = "Canal 10 - 22 - grandes",
                marker={'color' : '#cbd5e8'},
                text=qo.values,
                orientation='v'
              )



layout = go.Layout(
title= 'Canal 10 - grandes' ,
#barmode = 'stack',
width=1300,
height=450
)
#data = [trace0,trace1,trace2]
data = [trace1,trace2]
figure2 = go.Figure(data=data, layout=layout)
# Hide grid lines
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)
figure2.update_layout(
    autosize=False,
    width= 1300,
    height=400
)
figure2.update_traces(textposition='inside')
figure2.update_yaxes(showticklabels=True)
figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.update_xaxes(tickangle=30)
# Out:
# <div>                            <div id="a51d9de4-4aac-4761-b5ef-fc7c88f47d4b" class="plotly-graph-div" style="height:400px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a51d9de4-4aac-4761-b5ef-fc7c88f47d4b")) {                    Plotly.newPlot(                        "a51d9de4-4aac-4761-b5ef-fc7c88f47d4b",                        [{"marker":{"color":"#fdcdac"},"name":"Canal 10 - 23 - grandes","orientation":"v","text":[88983.46,91602.38,109625.2,116688.15,145411.42,131318.05,146878.91,139075.32,136454.18],"x":["01","02","03","04","05","06","07","08","09"],"y":[88983.46,91602.38,109625.2,116688.15,145411.42,131318.05,146878.91,139075.32,136454.18],"type":"bar","textposition":"inside"},{"marker":{"color":"#cbd5e8"},"name":"Canal 10 - 22 - grandes","orientation":"v","text":[90541.93,90103.87
# ...

# %%
qd =  grandes10_23.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qo =  grandes10_22.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qd = round(qd, 2)
qo = round(qo, 2)

trace1 = go.Bar(y=qd.values,
                x=qd.index,
                name = "Canal 10 - 23 - grandes",
                marker= dict (color ='#fdcdac' ),
                text=qd.values,
                orientation='v'
              )

trace2 = go.Bar(y=qo.values,
                x=qo.index,
                name = "Canal 10 - 22 - grandes",
                marker={'color' : '#cbd5e8'},
                text=qo.values,
                orientation='v'
              )



layout = go.Layout(
title= 'Canal 10 - grandes' ,
#barmode = 'stack',
width=1300,
height=450
)
#data = [trace0,trace1,trace2]
data = [trace1,trace2]
figure2 = go.Figure(data=data, layout=layout)
# Hide grid lines
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)
figure2.update_layout(
    autosize=False,
    width= 1300,
    height=400
)
figure2.update_traces(textposition='inside')
figure2.update_yaxes(showticklabels=True)
figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.update_xaxes(tickangle=30)
# Out:
# <div>                            <div id="7560e4dc-bab8-4abd-96eb-9bb585abfb0e" class="plotly-graph-div" style="height:400px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7560e4dc-bab8-4abd-96eb-9bb585abfb0e")) {                    Plotly.newPlot(                        "7560e4dc-bab8-4abd-96eb-9bb585abfb0e",                        [{"marker":{"color":"#fdcdac"},"name":"Canal 10 - 23 - grandes","orientation":"v","text":[27760.6,27234.0,27076.1,23390.0,48632.9,153874.25,134120.1,208131.67,14175.0,1086.0,440556.45],"x":["BAHIA","ESPIRITO SANTO","GOIAS","MARANHAO","MATO GROSSO DO SUL","MINAS GERAIS","PARANA","RIO DE JANEIRO","RIO GRANDE DO SUL","SANTA CATARINA","SAO PAULO"],"y":[27760.6,27234.0,27076.1,23390.0,48632.9,153874.25,134120.1,208131.67,14175.0,1086.0,440556.45],"type":"bar","textpo
# ...

# %%
#Brasil var grandes

grandes10_ = grandes10.groupby(["GRUPO","ds"])
grandes10_vol = grandes10_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(grandes10_vol, 
            x="ds", 
            y="VolANP",
            title="BR - Volume m³ - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="7b468546-b2f2-446f-94ef-c88db90d84dc" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b468546-b2f2-446f-94ef-c88db90d84dc")) {                    Plotly.newPlot(                        "7b468546-b2f2-446f-94ef-c88db90d84dc",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol"
# ...

# %%
#Brasil var grandes

grandes10_ = grandes10.groupby(["GRUPO","ds"])
grandes10_vol = grandes10_.agg({"var":"sum"}).reset_index()


fig =px.line(grandes10_vol, 
            x="ds", 
            y="var",
            title="BR - Tendência - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="ac159ff2-fc53-40b0-9768-861e8afda794" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac159ff2-fc53-40b0-9768-861e8afda794")) {                    Plotly.newPlot(                        "ac159ff2-fc53-40b0-9768-861e8afda794",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"c
# ...

# %%
qd =  grandes10_23.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qo =  grandes10_23.groupby(by='NOM_ESTADO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="Volume m³ - por UF de origem - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="482f09b4-a568-4fa2-9712-0e9ddd1d7261" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("482f09b4-a568-4fa2-9712-0e9ddd1d7261")) {                    Plotly.newPlot(                        "482f09b4-a568-4fa2-9712-0e9ddd1d7261",                        [{"alignmentgroup":"True","hovertemplate":"NOM_ESTADO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[440556.45,208131.67,153874.25,134120.1,48632.9,27760.6,27234.0,27076.1,23390.0,14175.0,1086.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["SAO PAULO","RIO DE JANEIRO","MINAS GERAIS","PARANA","M
# ...

# %% [markdown]
# # SP

# %%
#Brasil var grandes

grandes10_SP_ = grandes10_SP.groupby(["GRUPO","ds"])
grandes10_SP_vol = grandes10_SP_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(grandes10_SP_vol, 
            x="ds", 
            y="VolANP",
            title="SP - Volume m³ - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="f2db68d6-9499-4a4a-9166-58a1e760f9a7" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2db68d6-9499-4a4a-9166-58a1e760f9a7")) {                    Plotly.newPlot(                        "f2db68d6-9499-4a4a-9166-58a1e760f9a7",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol"
# ...

# %%
#Brasil var grandes

grandes10_SP_ = grandes10_SP.groupby(["GRUPO","ds"])
grandes10_SP_vol = grandes10_SP_.agg({"var":"sum"}).reset_index()


fig =px.line(grandes10_SP_vol, 
            x="ds", 
            y="var",
            title="SP - Tendência - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="3d575e75-f318-4aec-90e0-c36a5c20afdb" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d575e75-f318-4aec-90e0-c36a5c20afdb")) {                    Plotly.newPlot(                        "3d575e75-f318-4aec-90e0-c36a5c20afdb",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"c
# ...

# %%
qd =  grandes10_SP_23.groupby(by='NOM_MUNICIPIO_dest')['VolANP'].sum()
qo =  grandes10_SP_23.groupby(by='NOM_MUNICIPIO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="SP - Volume m³ - por MUNICÍPIO de DESTINO - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="a8713342-0d70-4c38-be8b-cdc65fa9c2b6" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8713342-0d70-4c38-be8b-cdc65fa9c2b6")) {                    Plotly.newPlot(                        "a8713342-0d70-4c38-be8b-cdc65fa9c2b6",                        [{"alignmentgroup":"True","hovertemplate":"NOM_MUNICIPIO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[178966.3,39263.4,26678.1,18260.0,17872.8,16878.65,16593.2,12485.0,11431.9,10056.0,9660.6,8508.5,7454.5,7321.2,6792.2,6500.5,6421.6,6056.7,6033.3,5803.0,4738.0,4019.5,3731.5,3668.0,2060.0,1662.0,725.0,710.0,205.0,0.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","s
# ...

# %%
qd =  grandes10_SP_23.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qo =  grandes10_SP_23.groupby(by='NOM_RAZAO_SOCIAL_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="SP - Volume m³ - por Empresa destino  - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="a7ff1c2b-62b8-45b2-9742-49c557c7cabf" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7ff1c2b-62b8-45b2-9742-49c557c7cabf")) {                    Plotly.newPlot(                        "a7ff1c2b-62b8-45b2-9742-49c557c7cabf",                        [{"alignmentgroup":"True","hovertemplate":"NOM_RAZAO_SOCIAL_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[178966.3,130371.2,52931.9,39263.4,21920.0,16878.65,225.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["RUMO MALHA PAULISTA S.A","RAIZEN ENERGIA S.A","SAO MARTINHO S/A","Ferrovia Centro Atl
# ...

# %%
figure2=px.histogram(
    (grandes10_SP_23.sort_values(by=['VolANP'], ascending=True)
    ),
    x="VolANP",
    y="NOM_RAZAO_SOCIAL_dest",
    title="grandes SP - share por Empresa",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="82bde2f2-8f1d-4075-9105-60109e31d3db" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82bde2f2-8f1d-4075-9105-60109e31d3db")) {                    Plotly.newPlot(                        "82bde2f2-8f1d-4075-9105-60109e31d3db",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=VIBRA<br>sum of VolANP (normalized as percent)=%{x}<br>NOM_RAZAO_SOCIAL_dest=%{y}<extra></extra>","legendgroup":"VIBRA","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"VIBRA","offsetgroup":"VIBRA","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[-45.0,5.0,10.0,10.0,20.0,20.0,25.0,25.0,25.0,25.0,35.0,40.0,45.0,90.0,100.0,105.0,110.0,110.0,11
# ...

# %%
grandes10_SP_23['NOM_RAZAO_SOCIAL_dest'].value_counts()
# Out:
# RAIZEN ENERGIA S.A                      284
# RUMO MALHA PAULISTA S.A                  47
# SUZANO S.A                               40
# SAO MARTINHO S/A                         39
# MRS LOGÍSTICA S/A                        18
# Ferrovia Centro Atlântica S.A. - FCA      9
# KLABIN S/A.                               9
# Name: NOM_RAZAO_SOCIAL_dest, dtype: int64

# %%
grandes10_SP_23 = round(grandes10_SP_23, 2)
_grandes10_SP_23_ = grandes10_SP_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","ds"])
grandes10_SP_23_ = _grandes10_SP_23_.agg({"VolANP":"sum"}).reset_index()


figure2=px.histogram(
    (grandes10_SP_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['KLABIN S/A.']")
    ),
    x="VolANP",
    y="ds",
    title="grandes SP - share - KLABIN S/A.",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=550
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="55b799e6-2aa2-4120-94ec-6f900d0cb722" class="plotly-graph-div" style="height:550px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55b799e6-2aa2-4120-94ec-6f900d0cb722")) {                    Plotly.newPlot(                        "55b799e6-2aa2-4120-94ec-6f900d0cb722",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>ds=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[10.0,10.0,10.0,10.0],"xaxis":"x","y":["2023-07-01T00:00:00","2023-09-01T00:00:00","2023-04-01T00:00:00","2023-0
# ...

# %% [markdown]
# # PR

# %%
#Brasil var grandes

grandes10_PR_ = grandes10_PR.groupby(["GRUPO","ds"])
grandes10_PR_vol = grandes10_PR_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(grandes10_PR_vol, 
            x="ds", 
            y="VolANP",
            title="PR - Volume m³ - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="96708a5d-134d-4cc2-8669-6e0f966f8ec5" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96708a5d-134d-4cc2-8669-6e0f966f8ec5")) {                    Plotly.newPlot(                        "96708a5d-134d-4cc2-8669-6e0f966f8ec5",                        [{"customdata":[["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"RAIZEN","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAIZEN","o
# ...

# %%
#Brasil var grandes

grandes10_PR_ = grandes10_PR.groupby(["GRUPO","ds"])
grandes10_PR_vol = grandes10_PR_.agg({"var":"sum"}).reset_index()


fig =px.line(grandes10_PR_vol, 
            x="ds", 
            y="var",
            title="PR - Tendência - canal 10 - cluster grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="fcaa372e-5a18-4996-9f60-bfb5a1dcf9dd" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcaa372e-5a18-4996-9f60-bfb5a1dcf9dd")) {                    Plotly.newPlot(                        "fcaa372e-5a18-4996-9f60-bfb5a1dcf9dd",                        [{"customdata":[["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"],["RAIZEN"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"RAIZEN","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAIZEN","orie
# ...

# %%
qd =  grandes10_PR_23.groupby(by='NOM_MUNICIPIO_dest')['VolANP'].sum()
qo =  grandes10_PR_23.groupby(by='NOM_MUNICIPIO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="PR - Volume m³ - por MUNICÍPIO de DESTINO - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="c2da5ae1-8d1b-41ae-aba4-9c99df1d9058" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2da5ae1-8d1b-41ae-aba4-9c99df1d9058")) {                    Plotly.newPlot(                        "c2da5ae1-8d1b-41ae-aba4-9c99df1d9058",                        [{"alignmentgroup":"True","hovertemplate":"NOM_MUNICIPIO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[70497.9,32759.2,30863.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["CURITIBA","ORTIGUEIRA","TELEMACO BORBA"],"xaxis":"x","y":[70497.9,32759.2,30863.0],"yaxis":"y","type":"bar"}],           
# ...

# %%
qd =  grandes10_PR_23.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qo =  grandes10_PR_23.groupby(by='NOM_RAZAO_SOCIAL_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="PR - Volume m³ - por Empresa destino  - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="7ca83cd1-c830-4e6d-8f36-bd17132f58b7" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ca83cd1-c830-4e6d-8f36-bd17132f58b7")) {                    Plotly.newPlot(                        "7ca83cd1-c830-4e6d-8f36-bd17132f58b7",                        [{"alignmentgroup":"True","hovertemplate":"NOM_RAZAO_SOCIAL_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[70497.9,63622.2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["RUMO MALHA SUL S.A","KLABIN S/A."],"xaxis":"x","y":[70497.9,63622.2],"yaxis":"y","type":"bar"}],                        {"temp
# ...

# %%
figure2=px.histogram(
    (grandes10_PR_23.sort_values(by=['VolANP'], ascending=True)
    ),
    x="VolANP",
    y="NOM_RAZAO_SOCIAL_dest",
    title="grandes PR - share por Empresa",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="563cef55-d573-4495-a045-76a5c5823d1c" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("563cef55-d573-4495-a045-76a5c5823d1c")) {                    Plotly.newPlot(                        "563cef55-d573-4495-a045-76a5c5823d1c",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>NOM_RAZAO_SOCIAL_dest=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[30.0,35.0,45.0,45.0,49.0,78.0,82.0,98.0,117.0,135.0,164.0,165.0,175.0,177.0,190.0,195.0,195.
# ...

# %%
grandes10_PR_23 = round(grandes10_PR_23, 2)
_grandes10_PR_23_ = grandes10_PR_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","mes"])
grandes10_PR_23_ = _grandes10_PR_23_.agg({"VolANP":"sum"}).reset_index()


figure2=px.histogram(
    (grandes10_PR_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['KLABIN S/A.']")
    ),
    x="VolANP",
    y="mes",
    title="grandes PR - share - KLABIN S/A.",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="45a0048e-987c-4409-bd1f-7d31472504b6" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45a0048e-987c-4409-bd1f-7d31472504b6")) {                    Plotly.newPlot(                        "45a0048e-987c-4409-bd1f-7d31472504b6",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=VIBRA<br>sum of VolANP (normalized as percent)=%{x}<br>mes=%{y}<extra></extra>","legendgroup":"VIBRA","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"VIBRA","offsetgroup":"VIBRA","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[1339.0,1463.0,1622.0,1640.0,1748.0,1773.0,1848.0,2013.5,2282.5],"xaxis":"x","y":["04","02","06","03","05","01","08
# ...

# %% [markdown]
# # medio_grandes

# %%
mask1 = dfcf["faixa_razao"] == "medio_grandes"
medio_grandes10 = dfcf[mask1]

mask1 = medio_grandes10["ano"] == "2023"
medio_grandes10_23 = medio_grandes10[mask1]
#medio_grandes10_23.info()


mask1 = medio_grandes10["ano"] == "2022"
medio_grandes10_22 = medio_grandes10[mask1]
#medio_grandes10_22.info()

# %%
qd =  medio_grandes10_23.groupby(by='mes')['VolANP'].sum()
qo =  medio_grandes10_22.groupby(by='mes')['VolANP'].sum()
qd = round(qd, 2)
qo = round(qo, 2)

trace1 = go.Bar(y=qd.values,
                x=qd.index,
                name = "Canal 10 - 23 - medio_grandes",
                marker= dict (color ='#fdcdac' ),
                text=qd.values,
                orientation='v'
              )

trace2 = go.Bar(y=qo.values,
                x=qo.index,
                name = "Canal 10 - 22 - medio_grandes",
                marker={'color' : '#cbd5e8'},
                text=qo.values,
                orientation='v'
              )



layout = go.Layout(
title= 'Canal 10 - medio_grandes' ,
#barmode = 'stack',
width=1300,
height=450
)
#data = [trace0,trace1,trace2]
data = [trace1,trace2]
figure2 = go.Figure(data=data, layout=layout)
# Hide grid lines
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)
figure2.update_layout(
    autosize=False,
    width= 1300,
    height=400
)
figure2.update_traces(textposition='inside')
figure2.update_yaxes(showticklabels=True)
figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.update_xaxes(tickangle=30)
# Out:
# <div>                            <div id="5064f051-2231-4c01-9a34-6b1699a8a280" class="plotly-graph-div" style="height:400px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5064f051-2231-4c01-9a34-6b1699a8a280")) {                    Plotly.newPlot(                        "5064f051-2231-4c01-9a34-6b1699a8a280",                        [{"marker":{"color":"#fdcdac"},"name":"Canal 10 - 23 - medio_grandes","orientation":"v","text":[75961.27,73288.53,89744.13,95335.05,118193.02,112214.79,122210.54,127209.66,119920.73],"x":["01","02","03","04","05","06","07","08","09"],"y":[75961.27,73288.53,89744.13,95335.05,118193.02,112214.79,122210.54,127209.66,119920.73],"type":"bar","textposition":"inside"},{"marker":{"color":"#cbd5e8"},"name":"Canal 10 - 22 - medio_grandes","orientation":"v","text":[67596.7
# ...

# %%
qd =  medio_grandes10_23.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qo =  medio_grandes10_22.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qd = round(qd, 2)
qo = round(qo, 2)

trace1 = go.Bar(y=qd.values,
                x=qd.index,
                name = "Canal 10 - 23 - medio_grandes",
                marker= dict (color ='#fdcdac' ),
                text=qd.values,
                orientation='v'
              )

trace2 = go.Bar(y=qo.values,
                x=qo.index,
                name = "Canal 10 - 22 - medio_grandes",
                marker={'color' : '#cbd5e8'},
                text=qo.values,
                orientation='v'
              )



layout = go.Layout(
title= 'Canal 10 - medio_grandes' ,
#barmode = 'stack',
width=1300,
height=450
)
#data = [trace0,trace1,trace2]
data = [trace1,trace2]
figure2 = go.Figure(data=data, layout=layout)
# Hide grid lines
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)
figure2.update_layout(
    autosize=False,
    width= 1300,
    height=400
)
figure2.update_traces(textposition='inside')
figure2.update_yaxes(showticklabels=True)
figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.update_xaxes(tickangle=30)
# Out:
# <div>                            <div id="327ef477-36cb-4d80-87a0-c5b9f8dca02a" class="plotly-graph-div" style="height:400px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327ef477-36cb-4d80-87a0-c5b9f8dca02a")) {                    Plotly.newPlot(                        "327ef477-36cb-4d80-87a0-c5b9f8dca02a",                        [{"marker":{"color":"#fdcdac"},"name":"Canal 10 - 23 - medio_grandes","orientation":"v","text":[500.0,162.0,8330.0,1475.0,12265.0,2285.0,67767.0,31744.29,97295.2,100423.03,166535.44,118569.31,505.0,82400.4,4655.0,60.0,1820.0,2740.0,2795.0,5206.65,2682.0,223567.4,190.0,105.0],"x":["ALAGOAS","AMAZONAS","BAHIA","CEARA","DISTRITO FEDERAL","ESPIRITO SANTO","GOIAS","MARANHAO","MATO GROSSO","MATO GROSSO DO SUL","MINAS GERAIS","PARA","PARAIBA","PARANA","PERNAMBUCO","PIA
# ...

# %%
#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="VolANP",
            title="BR - Volume m³ - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="e8813e55-42ca-4f27-b632-f59e12cd571f" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8813e55-42ca-4f27-b632-f59e12cd571f")) {                    Plotly.newPlot(                        "e8813e55-42ca-4f27-b632-f59e12cd571f",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol"
# ...

# %%
#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"var":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="var",
            title="BR - Tendência - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="693af3b0-80fb-4393-8c05-362274b9b341" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("693af3b0-80fb-4393-8c05-362274b9b341")) {                    Plotly.newPlot(                        "693af3b0-80fb-4393-8c05-362274b9b341",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"c
# ...

# %%
qd =  medio_grandes10_23.groupby(by='NOM_ESTADO_dest')['VolANP'].sum()
qo =  medio_grandes10_23.groupby(by='NOM_ESTADO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="Volume m³ - por UF de origem - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="aa7b0f8b-88c3-4f59-8ba3-af9746916208" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa7b0f8b-88c3-4f59-8ba3-af9746916208")) {                    Plotly.newPlot(                        "aa7b0f8b-88c3-4f59-8ba3-af9746916208",                        [{"alignmentgroup":"True","hovertemplate":"NOM_ESTADO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[223567.4,166535.44,118569.31,100423.03,97295.2,82400.4,67767.0,31744.29,12265.0,8330.0,5206.65,4655.0,2795.0,2740.0,2682.0,2285.0,1820.0,1475.0,505.0,500.0,190.0,162.0,105.0,60.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","
# ...

# %%
mask1 = medio_grandes10["NOM_ESTADO_dest"] == "SAO PAULO"
medio_grandes10_SP = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "MINAS GERAIS"
medio_grandes10_MG = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "PARANA"
medio_grandes10_PR = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "GOIAS"
medio_grandes10_GO = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "PARA"
medio_grandes10_PA = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "MATO GROSSO DO SUL"
medio_grandes10_MS = medio_grandes10[mask1]

mask1 = medio_grandes10["NOM_ESTADO_dest"] == "MATO GROSSO"
medio_grandes10_MT = medio_grandes10[mask1]


mask1 = medio_grandes10_SP["ano"] == "2023"
medio_grandes10_SP_23 = medio_grandes10_SP[mask1]

mask1 = medio_grandes10_MG["ano"] == "2023"
medio_grandes10_MG_23 = medio_grandes10_MG[mask1]

mask1 = medio_grandes10_PR["ano"] == "2023"
medio_grandes10_PR_23 = medio_grandes10_PR[mask1]

mask1 = medio_grandes10_PA["ano"] == "2023"
medio_grandes10_PA_23 = medio_grandes10_PA[mask1]

mask1 = medio_grandes10_MS["ano"] == "2023"
medio_grandes10_MS_23 = medio_grandes10_MS[mask1]

mask1 = medio_grandes10_MT["ano"] == "2023"
medio_grandes10_MT_23 = medio_grandes10_MT[mask1]

mask1 = medio_grandes10_GO["ano"] == "2023"
medio_grandes10_GO_23 = medio_grandes10_GO[mask1]

# %%
#medio_grandes10_MT_vol

# %% [markdown]
# # MT

# %%
#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10_MT.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="VolANP",
            title="BR - Volume m³ - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="968f4644-66af-4772-bc0d-6b76217d80be" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("968f4644-66af-4772-bc0d-6b76217d80be")) {                    Plotly.newPlot(                        "968f4644-66af-4772-bc0d-6b76217d80be",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol"
# ...

# %%
#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10_MT.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"var":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="var",
            title="BR - Tendência - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="e3304791-d107-499c-bbbd-9bb758497489" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3304791-d107-499c-bbbd-9bb758497489")) {                    Plotly.newPlot(                        "e3304791-d107-499c-bbbd-9bb758497489",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"c
# ...

# %%
qd =  medio_grandes10_MT_23.groupby(by='NOM_MUNICIPIO_dest')['VolANP'].sum()
qo =  medio_grandes10_MT_23.groupby(by='NOM_MUNICIPIO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="MT - Volume m³ - por MUNICÍPIO de DESTINO - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="42d328a3-f3c4-454e-8a17-75b1805fc92f" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42d328a3-f3c4-454e-8a17-75b1805fc92f")) {                    Plotly.newPlot(                        "42d328a3-f3c4-454e-8a17-75b1805fc92f",                        [{"alignmentgroup":"True","hovertemplate":"NOM_MUNICIPIO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[33019.0,15704.5,8214.8,6120.1,5784.5,4769.6,3722.0,3313.6,2856.8,2405.6,2337.5,1867.6,1806.4,1055.0,891.0,689.6,656.0,495.0,472.0,453.0,265.0,251.6,145.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f
# ...

# %%
qd =  medio_grandes10_MT_23.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qo =  medio_grandes10_MT_23.groupby(by='NOM_RAZAO_SOCIAL_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="MT - Volume m³ - por Empresa destino  - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="3e84a336-d4f1-431d-a7e9-3123d56cb858" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e84a336-d4f1-431d-a7e9-3123d56cb858")) {                    Plotly.newPlot(                        "3e84a336-d4f1-431d-a7e9-3123d56cb858",                        [{"alignmentgroup":"True","hovertemplate":"NOM_RAZAO_SOCIAL_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[34926.6,30312.0,15238.5,6120.1,4330.0,3171.0,2770.0,217.0,120.0,90.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["BOM FUTURO AGRICOLA LTDA","ALL - AMERICA LATINA LOGISTICA MALHA NORTE S/A
# ...

# %%
qd =  medio_grandes10_23.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qo =  medio_grandes10_22.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qd = round(qd, 2)
qo = round(qo, 2)

qd.sort_values()
qo.sort_values()


qd = round(qd, 2)
qo = round(qo, 2)


trace1 = go.Bar(y=qd.values,
                x=qd.index,
                name = "Canal 10 - 23 - medio_grandes",
                marker= dict (color ='#fdcdac' ),
                text=qd.values,
                orientation='v'
              )

trace2 = go.Bar(y=qo.values,
                x=qo.index,
                name = "Canal 10 - 22 - medio_grandes",
                marker={'color' : '#cbd5e8'},
                text=qo.values,
                orientation='v'
              )



layout = go.Layout(
title= 'Canal 10 - medio_grandes' ,
#barmode = 'stack',
width=1300,
height=450
)
#data = [trace0,trace1,trace2]
data = [trace1,trace2]
figure2 = go.Figure(data=data, layout=layout)
# Hide grid lines
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)
figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_traces(textposition='inside')
figure2.update_yaxes(showticklabels=True)
figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.update_xaxes(tickangle=30)
# Out:
# <div>                            <div id="7fc07f65-fa20-4a45-bf85-ff598ecc00a9" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fc07f65-fa20-4a45-bf85-ff598ecc00a9")) {                    Plotly.newPlot(                        "7fc07f65-fa20-4a45-bf85-ff598ecc00a9",                        [{"marker":{"color":"#fdcdac"},"name":"Canal 10 - 23 - medio_grandes","orientation":"v","text":[38705.53,31952.18,30312.0,43212.63,26791.0,35106.6,27891.1,29517.0,51817.6,32369.2,27332.0,32930.5,27643.31,31374.29,32628.85,30630.0,39001.5,32074.13,27138.0,55119.9,25523.0,31514.0,37077.0,47061.4,30555.0,25977.0,52823.0],"x":["ADECOAGRO VALE DO IVINHEMA S.A.","ALCOA WORLD ALUMINA BRASIL LTDA","ALL - AMERICA LATINA LOGISTICA MALHA NORTE S/A","ANGLO AMERICAN MINERIO 
# ...

# %%
figure2=px.histogram(
    (medio_grandes10_MT_23.sort_values(by=['VolANP'], ascending=True)
    ),
    x="VolANP",
    y="NOM_RAZAO_SOCIAL_dest",
    title="grandes MT - share por Empresa",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="2626863c-be0c-4285-97a9-1d15335dd26f" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2626863c-be0c-4285-97a9-1d15335dd26f")) {                    Plotly.newPlot(                        "2626863c-be0c-4285-97a9-1d15335dd26f",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>NOM_RAZAO_SOCIAL_dest=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[3.0,3.0,6.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,15.0,15.0,15.0,20.0,22.0,22.0,22.0,22.0,
# ...

# %%
#medio_grandes10_MT_23['ds'] = medio_grandes10_MT_23['ds'].apply(pd.to_datetime)

# %%
medio_grandes10_MT_23['NOM_RAZAO_SOCIAL_dest'].value_counts()
# Out:
# BOM FUTURO AGRICOLA LTDA                                                        456
# JBS S/A                                                                          39
# COMANDO DIESEL TRANSPORTE E LOGISTICA LTDA                                       39
# VOTORANTIM CIMENTOS SA                                                           20
# MARTELLI TRANSPORTES LTDA.                                                       18
# ALL - AMERICA LATINA LOGISTICA MALHA NORTE S/A                                   18
# POLIMIX CONCRETO LTDA                                                            17
# COFCO INTERNATIONAL BRASIL S.A.                                                   9
# BRENCO - COMPANHIA BRASILEIRA DE ENERGIA RENOVAVEL - EM RECUPERACAO JUDICIAL      9
# EMPRESA GONTIJO DE TRANSPORTES LTDA                                               6
# Name: NOM_RAZAO_SOCIAL_dest, dtype: int64

# %%
medio_grandes10_MT_23 = round(medio_grandes10_MT_23, 2)
_medio_grandes10_MT_23_ = medio_grandes10_MT_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","mes"])
medio_grandes10_MT_23_ = _medio_grandes10_MT_23_.agg({"VolANP":"sum"}).reset_index()
medio_grandes10_MT_23_ = medio_grandes10_MT_23_.sort_values(by=['mes'], ascending=True)

figure2=px.histogram(
    (medio_grandes10_MT_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['BOM FUTURO AGRICOLA LTDA']")
    ),
    x="VolANP",
    y="mes",
    title="medio_grandes MT - share - BOM FUTURO AGRICOLA LTDA",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="94b66d60-3c90-4080-80d4-53507f30ce87" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94b66d60-3c90-4080-80d4-53507f30ce87")) {                    Plotly.newPlot(                        "94b66d60-3c90-4080-80d4-53507f30ce87",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=OUTRAS NP<br>sum of VolANP (normalized as percent)=%{x}<br>mes=%{y}<extra></extra>","legendgroup":"OUTRAS NP","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"OUTRAS NP","offsetgroup":"OUTRAS NP","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[60.0,60.0,76.0,118.0,173.0],"xaxis":"x","y":["03","08","09","02","01"],"yaxis":"y","type":"histogr
# ...

# %%
medio_grandes10_MT_23 = round(medio_grandes10_MT_23, 2)
_medio_grandes10_MT_23_ = medio_grandes10_MT_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","mes"])
medio_grandes10_MT_23_ = _medio_grandes10_MT_23_.agg({"VolANP":"sum"}).reset_index()
medio_grandes10_MT_23_ = medio_grandes10_MT_23_.sort_values(by=['mes'], ascending=True)

figure2=px.histogram(
    (medio_grandes10_MT_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['ALL - AMERICA LATINA LOGISTICA MALHA NORTE S/A']")
    ),
    x="VolANP",
    y="mes",
    title="medio_grandes MT - share - ALL - AMERICA LATINA LOGISTICA MALHA NORTE S/A",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="9ecf7fe5-377e-45bb-bce9-9f65978a1d78" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ecf7fe5-377e-45bb-bce9-9f65978a1d78")) {                    Plotly.newPlot(                        "9ecf7fe5-377e-45bb-bce9-9f65978a1d78",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>mes=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[2517.0,3127.0,3282.0,3323.0,3426.0,3521.0,3593.0,3721.0,3802.0],"xaxis":"x","y":["01","03","02","06","05","07"
# ...

# %%
medio_grandes10_MT_23 = round(medio_grandes10_MT_23, 2)
_medio_grandes10_MT_23_ = medio_grandes10_MT_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","mes"])
medio_grandes10_MT_23_ = _medio_grandes10_MT_23_.agg({"VolANP":"sum"}).reset_index()
medio_grandes10_MT_23_ = medio_grandes10_MT_23_.sort_values(by=['mes'], ascending=True)

figure2=px.histogram(
    (medio_grandes10_MT_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['MARTELLI TRANSPORTES LTDA.']")
    ),
    x="VolANP",
    y="mes",
    title="medio_grandes MT - share - MARTELLI TRANSPORTES LTDA.",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="50ce0018-71e0-41c3-b4d2-7aff0ec4f273" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50ce0018-71e0-41c3-b4d2-7aff0ec4f273")) {                    Plotly.newPlot(                        "50ce0018-71e0-41c3-b4d2-7aff0ec4f273",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>mes=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[88.0,104.0,165.0,192.0,358.0,508.0,554.0,922.0,1602.0],"xaxis":"x","y":["07","06","02","01","05","04","09","03
# ...

# %% [markdown]
# # MS

# %%
# MS

#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10_MS.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"VolANP":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="VolANP",
            title="BR - Volume m³ - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="20ddd6c4-c08f-4c07-8f44-4d6867d66323" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20ddd6c4-c08f-4c07-8f44-4d6867d66323")) {                    Plotly.newPlot(                        "20ddd6c4-c08f-4c07-8f44-4d6867d66323",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>VolANP=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"circle"},"m
# ...

# %%
#Brasil var medio_grandes

medio_grandes10_ = medio_grandes10_MS.groupby(["GRUPO","ds"])
medio_grandes10_vol = medio_grandes10_.agg({"var":"sum"}).reset_index()


fig =px.line(medio_grandes10_vol, 
            x="ds", 
            y="var",
            title="BR - Tendência - canal 10 - cluster medio_grandes",
            color="GRUPO",
            color_discrete_sequence=px.colors.qualitative.Pastel2,
            hover_data=["GRUPO"]
        )

fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="ee675774-08f0-4cb7-afd8-5d53ddad151c" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee675774-08f0-4cb7-afd8-5d53ddad151c")) {                    Plotly.newPlot(                        "ee675774-08f0-4cb7-afd8-5d53ddad151c",                        [{"customdata":[["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"],["IPIRANGA"]],"hovertemplate":"GRUPO=%{customdata[0]}<br>ds=%{x}<br>var=%{y}<extra></extra>","legendgroup":"IPIRANGA","line":{"color":"rgb(179,226,205)","dash":"solid"},"marker":{"symbol":"circle"},"mode
# ...

# %%
qd =  medio_grandes10_MS_23.groupby(by='NOM_MUNICIPIO_dest')['VolANP'].sum()
qo =  medio_grandes10_MS_23.groupby(by='NOM_MUNICIPIO_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="MS - Volume m³ - por MUNICÍPIO de DESTINO - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="b9ac17ea-39d5-4465-9cd2-e16021408e0e" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9ac17ea-39d5-4465-9cd2-e16021408e0e")) {                    Plotly.newPlot(                        "b9ac17ea-39d5-4465-9cd2-e16021408e0e",                        [{"alignmentgroup":"True","hovertemplate":"NOM_MUNICIPIO_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[33765.5,22703.9,16001.63,14901.5,7225.5,3795.0,818.0,603.0,299.0,245.0,35.0,30.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["TRES LAGOAS","IVINHEMA","ANGELICA","RIO BRILHANTE","COSTA RICA",
# ...

# %%
qd =  medio_grandes10_MS_23.groupby(by='NOM_RAZAO_SOCIAL_dest')['VolANP'].sum()
qo =  medio_grandes10_MS_23.groupby(by='NOM_RAZAO_SOCIAL_orig')['VolANP'].sum()
qd = round(qd, 2)
qd = qd.sort_values(ascending = False)
qo = round(qo, 2)
qo = qo.sort_values(ascending = False)

fig=px.bar(
    (qd
     #.query("QUALIF_DEST in ['TRR']")
     #.sort_values(ascending = False)
     #.nlargest(5)
     #.groupby("GRUPO", as_index=False)
     #.mean()
     #.rename({"expenditure_per_student": "Expenditure Per Student (Thousands)"}, axis=1)
     #.nlargest(10, 'VolANP_ano')
    ),
    x=qd.index,
    y=qd.values,
    title="MS - Volume m³ - por Empresa destino  - Ano 2023",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    color=qd.values,
    color_continuous_scale="deep",
    text_auto='.0f',
    #hover_data=["GRUPO"]
)


fig.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
    
fig.update_layout(
        title = {"x": .45, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa", 
        font=dict(size=11)
    )
fig.show()
# Out:
# <div>                            <div id="deb8cbfc-cf76-476a-bf69-ddb475407f34" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("deb8cbfc-cf76-476a-bf69-ddb475407f34")) {                    Plotly.newPlot(                        "deb8cbfc-cf76-476a-bf69-ddb475407f34",                        [{"alignmentgroup":"True","hovertemplate":"NOM_RAZAO_SOCIAL_dest=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[38705.53,32930.5,14901.5,7225.5,4891.0,865.0,659.0,245.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.0f}","x":["ADECOAGRO VALE DO IVINHEMA S.A.","ELDORADO CELULOSE","BIOSEV S.A.","BRENCO - COMPANHI
# ...

# %%
figure2=px.histogram(
    (medio_grandes10_MS_23.sort_values(by=['VolANP'], ascending=True)
    ),
    x="VolANP",
    y="NOM_RAZAO_SOCIAL_dest",
    title="grandes MS - share por Empresa",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="db364c99-6471-477c-9329-cbbb2ac70ede" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db364c99-6471-477c-9329-cbbb2ac70ede")) {                    Plotly.newPlot(                        "db364c99-6471-477c-9329-cbbb2ac70ede",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=IPIRANGA<br>sum of VolANP (normalized as percent)=%{x}<br>NOM_RAZAO_SOCIAL_dest=%{y}<extra></extra>","legendgroup":"IPIRANGA","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"IPIRANGA","offsetgroup":"IPIRANGA","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[5.0,5.0,5.0,10.0,41.0,41.0,45.0,49.33,65.0,84.0,86.0,99.0,125.0,127.0,128.0,168.0,20
# ...

# %%
#medio_grandes10_MS_23['ds'] = medio_grandes10_MS_23['ds'].apply(pd.to_datetime)

medio_grandes10_MS_23['NOM_RAZAO_SOCIAL_dest'].value_counts()


medio_grandes10_MS_23 = round(medio_grandes10_MS_23, 2)
_medio_grandes10_MS_23_ = medio_grandes10_MS_23.groupby(["NOM_RAZAO_SOCIAL_dest","GRUPO","mes"])
medio_grandes10_MS_23_ = _medio_grandes10_MS_23_.agg({"VolANP":"sum"}).reset_index()
medio_grandes10_MS_23_ = medio_grandes10_MS_23_.sort_values(by=['mes'], ascending=True)

figure2=px.histogram(
    (medio_grandes10_MS_23_
     .sort_values(by=['VolANP'], ascending=True)
     .query("NOM_RAZAO_SOCIAL_dest in ['ADECOAGRO VALE DO IVINHEMA S.A.']")
    ),
    x="VolANP",
    y="mes",
    title="medio_grandes MS - share - ADECOAGRO VALE DO IVINHEMA S.A.",
    color="GRUPO",
    color_discrete_sequence=px.colors.qualitative.Pastel2,
    barnorm='percent',
    text_auto='.2f',
    #hover_data=["QUALIF_DEST","GRUPO"],
    )

figure2.update_layout(
    autosize=False,
    width= 1300,
    height=700
)
figure2.update_xaxes(showgrid=False)
figure2.update_yaxes(showgrid=True)

figure2.update_layout(
        title = {"x": .5, "y": .90, "font": {"color":"darkslateblue"}},
        plot_bgcolor = "#fcfafa",
        paper_bgcolor = "#fcfafa"
    )
figure2.show()
# Out:
# <div>                            <div id="00155a90-b094-4b6c-9671-ee6756638d95" class="plotly-graph-div" style="height:700px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00155a90-b094-4b6c-9671-ee6756638d95")) {                    Plotly.newPlot(                        "00155a90-b094-4b6c-9671-ee6756638d95",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"GRUPO=RAIZEN<br>sum of VolANP (normalized as percent)=%{x}<br>mes=%{y}<extra></extra>","legendgroup":"RAIZEN","marker":{"color":"rgb(179,226,205)","pattern":{"shape":""}},"name":"RAIZEN","offsetgroup":"RAIZEN","orientation":"h","showlegend":true,"texttemplate":"%{value:.2f}","x":[180.0,1080.0,1440.0,1620.0,1976.0,2618.5,3211.5,3360.0,3374.0],"xaxis":"x","y":["02","04","01","03","05","07",
# ...

# %%
#!jupyter nbconvert --to html --no-input ANPgranular23-analiticocanal10-v14.ipynb
